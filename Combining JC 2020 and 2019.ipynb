# %%
import pandas as pd

# %%
#load in previously created csv
JC_data_2019 = pd.read_csv("Combined_JC_2019.csv")
JC_data_2019
# Out:
#         Unnamed: 0  tripduration                 starttime  \
# 0                0           201  2019-01-01 03:09:09.7110
# 1                1           505  2019-01-01 05:18:00.1060
# 2                2           756  2019-01-01 10:36:33.3400
# 3                3          1575  2019-01-01 12:43:38.6430
# 4                4          1566  2019-01-01 12:43:39.6010
# ...            ...           ...                       ...
# 262920       48706           384  2019-08-31 23:40:45.2450
# 262921       48707           633  2019-08-31 23:45:55.6660
# 262922       48708           324  2019-08-31 23:50:27.9220
# 262923       48709           126  2019-08-31 23:52:21.9250
# 262924       48710           690  2019-08-31 23:56:55.1530
#
#                         stoptime  start station id start station name  \
# 0       2019-01-01 03:12:30.8790              3183     Exchange Place
# 1       2019-01-01 05:26:25.9050              3183     Exchange Place
# ...

# %%
#load in previously created csv
JC_data_2020 = pd.read_csv("Combined_JC_2020.csv")
JC_data_2020
# Out:
#         Unnamed: 0  tripduration                 starttime  \
# 0                0           226  2020-01-01 00:04:50.1920
# 1                1           377  2020-01-01 00:16:01.6700
# 2                2           288  2020-01-01 00:17:33.8770
# 3                3           435  2020-01-01 00:32:05.9020
# 4                4           231  2020-01-01 00:46:19.6780
# ...            ...           ...                       ...
# 219909       43262           162  2020-08-31 23:43:15.8540
# 219910       43263           400  2020-08-31 23:46:19.9130
# 219911       43264           288  2020-08-31 23:47:16.8680
# 219912       43265           199  2020-08-31 23:50:37.2650
# 219913       43266           333  2020-08-31 23:55:30.8050
#
#                         stoptime  start station id start station name  \
# 0       2020-01-01 00:08:37.0370              3186      Grove St PATH
# 1       2020-01-01 00:22:19.0800              3186      Grove St PATH
# ...

# %%
#combine datasets
total_2019_2020_JC = pd.concat([JC_data_2019,JC_data_2020])
total_2019_2020_JC
# Out:
#         Unnamed: 0  tripduration                 starttime  \
# 0                0           201  2019-01-01 03:09:09.7110
# 1                1           505  2019-01-01 05:18:00.1060
# 2                2           756  2019-01-01 10:36:33.3400
# 3                3          1575  2019-01-01 12:43:38.6430
# 4                4          1566  2019-01-01 12:43:39.6010
# ...            ...           ...                       ...
# 219909       43262           162  2020-08-31 23:43:15.8540
# 219910       43263           400  2020-08-31 23:46:19.9130
# 219911       43264           288  2020-08-31 23:47:16.8680
# 219912       43265           199  2020-08-31 23:50:37.2650
# 219913       43266           333  2020-08-31 23:55:30.8050
#
#                         stoptime  start station id start station name  \
# 0       2019-01-01 03:12:30.8790              3183     Exchange Place
# 1       2019-01-01 05:26:25.9050              3183     Exchange Place
# ...

# %%
#output csv for load into Tableau
total_2019_2020_JC.to_csv("Combined_JC_2019_2020.csv")
