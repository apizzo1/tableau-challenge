# %%
import pandas as pd

# %%
bike_data_2016 = pd.read_csv("Q1_2016.csv")
bike_data_2017 = pd.read_csv("Q1_2017.csv")
bike_data_2018 = pd.read_csv("Q1_2018.csv")
bike_data_2019 = pd.read_csv("Q1_2019.csv")

# %%
bike_data_2019
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/19                                              22145
# 1    1/2/19                                              38249
# 2    1/3/19                                              42181
# 3    1/4/19                                              44420
# 4    1/5/19                                              17636
# ..      ...                                                ...
# 85  3/27/19                                              54483
# 86  3/28/19                                              58538
# 87  3/29/19                                              59324
# 88  3/30/19                                              66672
# 89  3/31/19                                              32768
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         44131
# 1                                         58975
# 2                                         62500
# ...

# %%
bike_data_2016_q2 = pd.read_csv("Q2_2016.csv")
bike_data_2017_q2 = pd.read_csv("Q2_2017.csv")
bike_data_2018_q2 = pd.read_csv("Q2_2018.csv")
bike_data_2019_q2 = pd.read_csv("Q2_2019.csv")

# %%
bike_data_2016_q3 = pd.read_csv("Q3_2016.csv")
bike_data_2017_q3 = pd.read_csv("Q3_2017.csv")
bike_data_2018_q3 = pd.read_csv("Q3_2018.csv")

# %%
bike_data_2016_q4 = pd.read_csv("Q4_2016.csv")
bike_data_2017_q4 = pd.read_csv("Q4_2017.csv")
bike_data_2018_q4 = pd.read_csv("Q4_2018.csv")

# %%
allquarter_compare = pd.concat([bike_data_2016,bike_data_2017,bike_data_2018,bike_data_2019,
                               bike_data_2016_q2,bike_data_2017_q2,bike_data_2018_q2,bike_data_2019_q2,
                               bike_data_2016_q3,bike_data_2017_q3,bike_data_2018_q3,
                               bike_data_2016_q4,bike_data_2017_q4,bike_data_2018_q4])
allquarter_compare
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2016                                              11009
# 1   1/2/2016                                              14587
# 2   1/3/2016                                              15499
# 3   1/4/2016                                              19593
# 4   1/5/2016                                              18053
# ..       ...                                                ...
# 87  12/27/18                                              31169
# 88  12/28/18                                              12039
# 89  12/29/18                                              29037
# 90  12/30/18                                              22536
# 91  12/31/18                                              18936
#
#    Cumulative trips (since launch):  \
# 0                          24371025
# 1                          24385612
# 2                          24401111
# 3                          24420704
# ...

# %%
combined_all_quarter_compare=allquarter_compare[["Date","Trips over the past 24-hours (midnight to 11:59pm)", "Miles traveled today (midnight to 11:59 pm)","24-Hour Passes Purchased (midnight to 11:59 pm)","Total Annual Members (All Time)","3-Day Passes Purchased (midnight to 11:59 pm)"]]

# %%
combined_all_quarter_compare
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2016                                              11009
# 1   1/2/2016                                              14587
# 2   1/3/2016                                              15499
# 3   1/4/2016                                              19593
# 4   1/5/2016                                              18053
# ..       ...                                                ...
# 87  12/27/18                                              31169
# 88  12/28/18                                              12039
# 89  12/29/18                                              29037
# 90  12/30/18                                              22536
# 91  12/31/18                                              18936
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         24429
# 1                                         29093
# ...

# %%
combined_all_quarter_compare.to_csv("Q1_Q2__Q3_Q4_overall_compare.csv")
