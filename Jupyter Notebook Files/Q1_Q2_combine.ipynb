# %%
import pandas as pd

# %%
#load q1 csvs
bike_data_2014 = pd.read_csv("Q1_2014.csv")
bike_data_2015 = pd.read_csv("Q1_2015.csv")
bike_data_2016 = pd.read_csv("Q1_2016.csv")
bike_data_2017 = pd.read_csv("Q1_2017.csv")
bike_data_2018 = pd.read_csv("Q1_2018.csv")
bike_data_2019 = pd.read_csv("Q1_2019.csv")

# %%
bike_data_2017
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/17                                              16009
# 1    1/2/17                                               8921
# 2    1/3/17                                              14198
# 3    1/4/17                                              34039
# 4    1/5/17                                              28393
# ..      ...                                                ...
# 85  3/27/17                                              26301
# 86  3/28/17                                              21590
# 87  3/29/17                                              42430
# 88  3/30/17                                              39746
# 89  3/31/17                                               6946
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         50761
# 1                                         21545
# 2                                         25879
# ...

# %%
bike_data_2014 = bike_data_2014.rename(columns={"Total Annual Members":"Total Annual Members (All Time)"})
bike_data_2014
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2014                                               6559
# 1    1/2/2014                                               9334
# 2    1/3/2014                                               1288
# 3    1/4/2014                                               2494
# 4    1/5/2014                                               2937
# ..        ...                                                ...
# 85  3/27/2014                                              18166
# 86  3/28/2014                                              20025
# 87  3/29/2014                                               4870
# 88  3/30/2014                                               8645
# 89  3/31/2014                                              18686
#
#     Cumulative trips (since launch):  \
# 0                            6323722
# 1                            6333056
# 2                            6334344
# ...

# %%
bike_data_2014_q2 = pd.read_csv("Q2_2014.csv")
bike_data_2015_q2 = pd.read_csv("Q2_2015.csv")
bike_data_2016_q2 = pd.read_csv("Q2_2016.csv")
bike_data_2017_q2 = pd.read_csv("Q2_2017.csv")
bike_data_2018_q2 = pd.read_csv("Q2_2018.csv")
bike_data_2019_q2 = pd.read_csv("Q2_2019.csv")

# %%
bike_data_2014_q2
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2014                                              26163
# 1    4/2/2014                                              24299
# 2    4/3/2014                                              28379
# 3    4/4/2014                                              13593
# 4    4/5/2014                                              20333
# ..        ...                                                ...
# 86  6/26/2014                                              38610
# 87  6/27/2014                                              39697
# 88  6/28/2014                                              31684
# 89  6/29/2014                                              30784
# 90  6/30/2014                                              36854
#
#     Cumulative trips (since launch):  \
# 0                            7395956
# 1                            7420255
# 2                            7448634
# ...

# %%
bike_data_2014_q2 = bike_data_2014_q2.rename(columns={"Total Annual Memberships Sold":"Total Annual Members (All Time)"})
bike_data_2014_q2
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2014                                              26163
# 1    4/2/2014                                              24299
# 2    4/3/2014                                              28379
# 3    4/4/2014                                              13593
# 4    4/5/2014                                              20333
# ..        ...                                                ...
# 86  6/26/2014                                              38610
# 87  6/27/2014                                              39697
# 88  6/28/2014                                              31684
# 89  6/29/2014                                              30784
# 90  6/30/2014                                              36854
#
#     Cumulative trips (since launch):  \
# 0                            7395956
# 1                            7420255
# 2                            7448634
# ...

# %%
bike_data_2015_q2 = bike_data_2015_q2.rename(columns={"Total Annual Memberships Sold":"Total Annual Members (All Time)"})
bike_data_2015_q2
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/2015                                              21566
# 1    4/2/2015                                              26346
# 2    4/3/2015                                              15978
# 3    4/4/2015                                              15538
# 4    4/5/2015                                              14962
# ..        ...                                                ...
# 86  6/26/2015                                              40599
# 87  6/27/2015                                              16271
# 88  6/28/2015                                              21588
# 89  6/29/2015                                              39785
# 90  6/30/2015                                              39839
#
#     Cumulative trips (since launch)  \
# 0                          16137578
# 1                          16163924
# 2                          16179902
# ...

# %%
q1__q2_compare = pd.concat([bike_data_2014,bike_data_2015,bike_data_2016,bike_data_2017,bike_data_2018, bike_data_2019,\
                           bike_data_2014_q2,bike_data_2015_q2,bike_data_2016_q2,bike_data_2017_q2,bike_data_2018_q2,bike_data_2019_q2])
q1__q2_compare
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2014                                               6559
# 1   1/2/2014                                               9334
# 2   1/3/2014                                               1288
# 3   1/4/2014                                               2494
# 4   1/5/2014                                               2937
# ..       ...                                                ...
# 66    6/6/19                                              81323
# 67    6/7/19                                              82908
# 68    6/8/19                                              78074
# 69    6/9/19                                              73954
# 70   6/10/19                                              37019
#
#     Cumulative trips (since launch):  \
# 0                          6323722.0
# 1                          6333056.0
# 2                          6334344.0
# 3                          6336838.0
# ...

# %%
combined_q1_q2_compare=q1__q2_compare[["Date","Trips over the past 24-hours (midnight to 11:59pm)", "Miles traveled today (midnight to 11:59 pm)","24-Hour Passes Purchased (midnight to 11:59 pm)","Total Annual Members (All Time)","3-Day Passes Purchased (midnight to 11:59 pm)"]]

# %%
combined_q1_q2_compare
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2014                                               6559
# 1   1/2/2014                                               9334
# 2   1/3/2014                                               1288
# 3   1/4/2014                                               2494
# 4   1/5/2014                                               2937
# ..       ...                                                ...
# 66    6/6/19                                              81323
# 67    6/7/19                                              82908
# 68    6/8/19                                              78074
# 69    6/9/19                                              73954
# 70   6/10/19                                              37019
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         9.254
# 1                                        11.736
# ...

# %%
combined_q1_q2_compare.to_csv("Q1_Q2_overall_compare.csv")
